# %%
# %pip install selenium pandas openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time
import pandas as pd

# Cấu hình Selenium
options = webdriver.ChromeOptions()
options.add_argument("--headless")
options.add_argument("--no-sandbox")
options.add_argument("--disable-dev-shm-usage")

# Mở trình duyệt
driver = webdriver.Chrome(options=options)

# Mở trang Looker Studio
url = "https://lookerstudio.google.com/u/0/reporting/6a99f06c-f0a9-4aa8-8d68-058b1afdb6a5/page/cOHMD?s=pKnsq0u7hHc"
driver.get(url)
time.sleep(5)

# Hàm lấy dữ liệu điểm từ trang web
def get_candidate_data(candidate_id):
    try:
        # Tìm ô nhập số báo danh và nhập số
        input_box = driver.find_element(By.XPATH, '//*[@id="input_1"]')
        input_box.clear()
        input_box.send_keys(str(candidate_id))
        input_box.send_keys(Keys.RETURN)
        time.sleep(5)
        # Lấy dữ liệu điểm từ trang web
        data = {
            "Số báo danh": candidate_id,
            "Toán KC": driver.find_element(By.XPATH, '//*[@id="body"]/div[2]/div/ng2-reporting-plate/plate/div/div/div/div[1]/div/div/div/div/div/canvas-pancake-adapter/canvas-layout/div/div/div/div/div/div/ng2-report/ng2-canvas-container/div/div[4]/ng2-canvas-component/div/div/div/div/table-wrapper/div/ng2-table/div/div[3]/div[2]/div[2]/div[1]').text,
            "Văn KC": driver.find_element(By.XPATH, '//*[@id="body"]/div[2]/div/ng2-reporting-plate/plate/div/div/div/div[1]/div/div/div/div/div/canvas-pancake-adapter/canvas-layout/div/div/div/div/div/div/ng2-report/ng2-canvas-container/div/div[4]/ng2-canvas-component/div/div/div/div/table-wrapper/div/ng2-table/div/div[3]/div[2]/div[2]/div[2]').text,
            "Anh KC": driver.find_element(By.XPATH, '//*[@id="body"]/div[2]/div/ng2-reporting-plate/plate/div/div/div/div[1]/div/div/div/div/div/canvas-pancake-adapter/canvas-layout/div/div/div/div/div/div/ng2-report/ng2-canvas-container/div/div[4]/ng2-canvas-component/div/div/div/div/table-wrapper/div/ng2-table/div/div[3]/div[2]/div[2]/div[3]').text,
            "Toán CH": driver.find_element(By.XPATH, '//*[@id="body"]/div[2]/div/ng2-reporting-plate/plate/div/div/div/div[1]/div/div/div/div/div/canvas-pancake-adapter/canvas-layout/div/div/div/div/div/div/ng2-report/ng2-canvas-container/div/div[4]/ng2-canvas-component/div/div/div/div/table-wrapper/div/ng2-table/div/div[3]/div[2]/div[2]/div[4]').text,
            "Tin CH": driver.find_element(By.XPATH, '//*[@id="body"]/div[2]/div/ng2-reporting-plate/plate/div/div/div/div[1]/div/div/div/div/div/canvas-pancake-adapter/canvas-layout/div/div/div/div/div/div/ng2-report/ng2-canvas-container/div/div[4]/ng2-canvas-component/div/div/div/div/table-wrapper/div/ng2-table/div/div[3]/div[2]/div[2]/div[5]').text,
            "Lý CH": driver.find_element(By.XPATH, '//*[@id="body"]/div[2]/div/ng2-reporting-plate/plate/div/div/div/div[1]/div/div/div/div/div/canvas-pancake-adapter/canvas-layout/div/div/div/div/div/div/ng2-report/ng2-canvas-container/div/div[4]/ng2-canvas-component/div/div/div/div/table-wrapper/div/ng2-table/div/div[3]/div[2]/div[2]/div[6]').text,
            "Hóa CH": driver.find_element(By.XPATH, '//*[@id="body"]/div[2]/div/ng2-reporting-plate/plate/div/div/div/div[1]/div/div/div/div/div/canvas-pancake-adapter/canvas-layout/div/div/div/div/div/div/ng2-report/ng2-canvas-container/div/div[4]/ng2-canvas-component/div/div/div/div/table-wrapper/div/ng2-table/div/div[3]/div[2]/div[2]/div[7]').text,
            "Sinh CH": driver.find_element(By.XPATH, '//*[@id="body"]/div[2]/div/ng2-reporting-plate/plate/div/div/div/div[1]/div/div/div/div/div/canvas-pancake-adapter/canvas-layout/div/div/div/div/div/div/ng2-report/ng2-canvas-container/div/div[4]/ng2-canvas-component/div/div/div/div/table-wrapper/div/ng2-table/div/div[3]/div[2]/div[2]/div[8]').text,
            "Văn CH": driver.find_element(By.XPATH, '//*[@id="body"]/div[2]/div/ng2-reporting-plate/plate/div/div/div/div[1]/div/div/div/div/div/canvas-pancake-adapter/canvas-layout/div/div/div/div/div/div/ng2-report/ng2-canvas-container/div/div[4]/ng2-canvas-component/div/div/div/div/table-wrapper/div/ng2-table/div/div[3]/div[2]/div[2]/div[9]').text,
            "Anh CH": driver.find_element(By.XPATH, '//*[@id="body"]/div[2]/div/ng2-reporting-plate/plate/div/div/div/div[1]/div/div/div/div/div/canvas-pancake-adapter/canvas-layout/div/div/div/div/div/div/ng2-report/ng2-canvas-container/div/div[4]/ng2-canvas-component/div/div/div/div/table-wrapper/div/ng2-table/div/div[3]/div[2]/div[2]/div[10]').text
        }
        return data
    except Exception as e:
        print(f"❌ Lỗi khi lấy dữ liệu cho {candidate_id}: {e}")
        return None

data_list = []
candidate_id = 230001  # Bắt đầu từ số báo danh đầu tiên

while True:
    result = get_candidate_data(candidate_id)
    if result is None:
        print(f"🔹 Không tìm thấy dữ liệu cho {candidate_id}. Kết thúc quá trình thu thập!")
        break  
    data_list.append(result)
    candidate_id += 1 

driver.quit()
# Out:
# ❌ Lỗi khi lấy dữ liệu cho 230561: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="body"]/div[2]/div/ng2-reporting-plate/plate/div/div/div/div[1]/div/div/div/div/div/canvas-pancake-adapter/canvas-layout/div/div/div/div/div/div/ng2-report/ng2-canvas-container/div/div[4]/ng2-canvas-component/div/div/div/div/table-wrapper/div/ng2-table/div/div[3]/div[2]/div[2]/div[1]"}
#   (Session info: chrome=135.0.7049.96); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF66975EFA5+77893]
# 	GetHandleVerifier [0x00007FF66975F000+77984]
# 	(No symbol) [0x00007FF6695291BA]
# 	(No symbol) [0x00007FF66957F16D]
# 	(No symbol) [0x00007FF66957F41C]
# 	(No symbol) [0x00007FF6695D2237]
# 	(No symbol) [0x00007FF6695A716F]
# 	(No symbol) [0x00007FF6695CF07F]
# 	(No symbol) [0x00007FF6695A6F03]
# 	(No symbol) [0x00007FF669570328]
# ...

# %%
# Điểm chuẩn
benchmarks = {
    "Toán CH": 30.7,
    "Văn CH": 28.3,
    "Anh CH": 28.2,
    "Tin CH": 22.5,
    "Hóa CH": 33,
    "Sinh CH": 28.6
}


df = pd.DataFrame(data_list)

# Xử lý giá trị rỗng & chuyển kiểu dữ liệu
df.replace('null', 0, inplace=True)

# %%
df
# Out:
#      Số báo danh Toán KC Văn KC Anh KC Toán CH Tin CH Lý CH Hóa CH Sinh CH  \
# 0         230001     9.5    5.5    6.4     7.8      0     0      0       0
# 1         230002     2.5      0      0       0      0     0    3.5       0
# 2         230003       0      0      0       0      0     0      0       0
# 3         230004       0      0      0       0      0     0      0       0
# 4         230005       0      0    3.8       0      0     0      0       0
# ..           ...     ...    ...    ...     ...    ...   ...    ...     ...
# 555       230556       0      0      0       0      0     0      0       0
# 556       230557       0      0      0       0      0     0      0       0
# 557       230558       0      0      0       0      0     0      0       0
# 558       230559       0      0      0       0      0     0      0       0
# 559       230560       0      0      0       0      0     0      0       0
#
#     Văn CH Anh CH
# 0        0      0
# 1        0      0
# ...

# %%
# Chuyển tất cả cột (trừ 'Số báo danh') sang float
for col in df.columns:
    if col != "Số báo danh":
        df[col] = df[col].astype(float, errors="ignore")

# %%
import pandas as pd

# Bảng điểm chuẩn
benchmarks = {
    "Toán CH": 30.7,
    "Văn CH": 28.3,
    "Anh CH": 28.2,
    "Tin CH": 22.5,
    "Hóa CH": 33,
    "Sinh CH": 28.6
}


# Đảm bảo tất cả các điểm là số thực (float), thay 'null' bằng 0
cols_to_convert = ["Toán KC", "Văn KC", "Anh KC"] + list(benchmarks.keys())
df[cols_to_convert] = df[cols_to_convert].apply(pd.to_numeric, errors="coerce").fillna(0)

# Xác định các môn chuyên
specialized_subjects = list(benchmarks.keys())

# Tạo danh sách mới lưu dữ liệu theo cột
data_list_specialized_subjects = []

for index, row in df.iterrows():
    specialized_taken = [sub for sub in specialized_subjects if row[sub] > 0]

    # Tạo dictionary để lưu dữ liệu của thí sinh
    candidate_data = {
        "Số báo danh": row["Số báo danh"],
    }

    # Ghi dữ liệu môn chuyên vào cột "Môn chuyên 1", "Môn chuyên 2", ...
    for i in range(2):
        if i < len(specialized_taken):
            sub = specialized_taken[i]
            candidate_data[f"Specialized Subjects {i+1}"] = sub
            candidate_data[f"Specialized Score {i+1}"] = row[sub]
            candidate_data[f"Specialized Score x 2 {i+1}"] = row[sub] * 2 
        else:
            candidate_data[f"Specialized Subjects {i+1}"] = "null"
            candidate_data[f"Specialized Score {i+1}"] = 0
            candidate_data[f"Specialized Score x 2 {i+1}"] = 0

    data_list_specialized_subjects.append(candidate_data)

# Tạo DataFrame từ danh sách dữ liệu
df_specialized = pd.DataFrame(data_list_specialized_subjects)

# %%
pass_list = []
fail_list = []

for index, row in df.iterrows():
    # Kiểm tra nếu 3 môn chính bị thiếu hoặc tất cả môn chuyên bị thiếu
    if row["Toán KC"] == 0 or row["Văn KC"] == 0 or row["Anh KC"] == 0 or all(row[sub] == 0 for sub in specialized_subjects):
        fail_list.append({**row, "Status": "Failed", "Remarks": "Not enough information", "Results": ""})
    else:
        base_score = row["Toán KC"] + row["Văn KC"] + row["Anh KC"]
        specialized_taken = [sub for sub in specialized_subjects if row[sub] > 0]

        result_details = []
        passed_subjects = []
        failed_subjects = []

        # Tính điểm cho từng môn chuyên
        for sub in specialized_taken:
            specialized_score_1 = df_specialized.loc[index, "Specialized Score x 2 1"]  # Điểm cột 1
            specialized_score_2 = df_specialized.loc[index, "Specialized Score x 2 2"]  # Điểm cột 2

            total_score_1 = base_score + specialized_score_1  # Tổng điểm với cột 1
            total_score_2 = base_score + specialized_score_2  # Tổng điểm với cột 2

            # Lưu kết quả vào danh sách theo format yêu cầu
            if specialized_score_1 > 0:
                result_details.append(f"{sub}: {total_score_1}")
            if specialized_score_2 > 0:  # Nếu cột 2 không phải 0 thì mới ghi
                result_details.append(f"{sub}: {total_score_2}")

            # Kiểm tra nếu ít nhất một tổ hợp đạt chuẩn
            if (specialized_score_1 > 0 and total_score_1 >= benchmarks.get(sub, float('inf'))) or \
               (specialized_score_2 > 0 and total_score_2 >= benchmarks.get(sub, float('inf'))):
                passed_subjects.append(sub)
            else:
                failed_subjects.append(sub)

        # Gộp các kết quả thành chuỗi
        result_string = "; ".join(result_details)

        # Nếu có ít nhất một môn đạt chuẩn, thì Pass
        if passed_subjects:
            pass_list.append({**row, "Status": "Pass", "Remarks": "; ".join(passed_subjects), "Results": result_string})

        # Nếu có ít nhất một môn không đạt chuẩn, thì cũng lưu vào danh sách Fail
        if failed_subjects:
            fail_list.append({**row, "Status": "Failed", "Remarks": "; ".join(failed_subjects), "Results": result_string})

# Tạo DataFrame từ danh sách Pass và Fail
df_pass = pd.DataFrame(pass_list)
df_fail = pd.DataFrame(fail_list)
df_pass["Số báo danh"] = df_pass["Số báo danh"].astype(int)
df_fail["Số báo danh"] = df_fail["Số báo danh"].astype(int)

# %%
df_pass.to_excel("Pass_Report.xlsx", index=False)
df_fail.to_excel("Failed_Report.xlsx", index=False)
